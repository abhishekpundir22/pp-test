# %% [markdown]
# # Make an API
#
# Launch the API
#
# ```
# python app/main.py
# ```
#
# Check the documentation
#
# http://localhost:8000/docs
#
# Open the file `app/main.py`
#
# ### 1 Fix it
#
# Make the application work using what you did in notebook `2-FAQ.ipynb`
#
# ### 2 Load questions at startup
#
# Using `startup event` from FastAPI (https://fastapi.tiangolo.com/advanced/events/)
#
# Load questions from json file [data/faq.json](data/faq.json)
#
# ### 3 Unit tests
#
# One unit test is already implemented in [tests/test_api.py](tests/test_api.py)
#
# to run it, execute
#
# ```
# python tests/test_api.py
# ```
#
# Organize you code to ease unit testing. Write some unit tests.
